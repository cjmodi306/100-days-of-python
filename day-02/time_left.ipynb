# %%
# Create a program using maths and f-Strings that tells us how many days, weeks, months we have left if we live until 90 years old.

# %%
age = int(input('Enter your age: '))

diff = 90-age

print("You have {} days, {} weeks and {} months left to live.".format(diff*365,diff*52,diff*12))
# Out:
# Enter your age: 56
# You have 12410 days, 1768 weeks and 408 months left to live.
