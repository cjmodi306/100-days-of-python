# %% [markdown]
# <a href="https://colab.research.google.com/github/cjmodi306/100-days-of-python/blob/main/day-01/num_charac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Count the number of characters in the entered name

# %%
name = input('Enter your name: ')
num_charac = len(name)
print('The number of characters in your name is {}'.format(num_charac))
# Out:
# Enter your name: Modi
# The number of characters in your name is 4
